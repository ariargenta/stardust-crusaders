# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %%
def createCanvas(resolution = 100):
    abscissa = np.linspace(-1, 1, resolution)
    ordinate = np.linspace(-1, 1, resolution)
    
    return np.meshgrid(abscissa, ordinate)

# %%
def drawShader(shaderFunction, resolution = 100):
    abscissa, ordinate = createCanvas(resolution)
    image = shaderFunction(abscissa, ordinate)
    
    plt.figure(figsize = (6, 6))
    plt.imshow(image, extent = [-1, 1, -1, 1], origin = "lower")
    plt.axis("equal")
    plt.show()

# %%
def designedShader(abscissa, ordinate):
    circle = np.sqrt(abscissa**2 + ordinate**2)
    
    return(circle < 0.5).astype(float)

# %%
drawShader(designedShader)
